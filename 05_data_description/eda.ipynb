# %%
# !pip install -U ydata-profiling[notebook,unicode,pyspark]

# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
items = pd.read_csv('items.csv', index_col=0)
# items = items.set_index(0)
images = pd.read_csv('images.csv', index_col=0)
paths = pd.read_csv('df_path.csv', index_col=0)
queries = pd.read_csv('queries.csv', index_col=0)

# %%
items.head(10)
# Out:
#          item_id  external_id                   StartTime  \
# 0  1770838001815   4004991576  2025-06-04 22:22:49.000250
# 1  1855194000055   4063202329  2025-06-04 17:18:41.829182
# 2  1856933500778   4163168195  2025-06-04 12:58:19.243206
# 3  1880407500165   4127198425  2025-06-02 19:48:45.359309
# 4  1906750000340   4439796913  2025-06-03 17:38:03.793379
# 5  1945975500069   4329218756  2025-06-01 23:30:46.563822
# 6  2002378751411   4573141268  2025-06-04 11:59:19.695653
# 7  2014645750367   4605179286  2025-06-03 09:26:30.814613
# 8  2023124500537   4553235097  2025-06-04 11:26:26.013679
# 9  2028008000083   4667761793  2025-06-04 15:26:07.292435
#
#                  param2   Microcat_id      sostoyanie       predmet_odezhdy  \
# 0      Рубашки и блузки          5943        Отличное      Рубашки и блузки
# 1       Топы и футболки          7479        Отличное       Топы и футболки
# 2                Другое          4488  Новое с биркой                Другое
# ...

# %%
items.columns
# Out:
# Index(['item_id', 'external_id', 'StartTime', 'param2', 'Microcat_id',
#        'sostoyanie', 'predmet_odezhdy', 'cvet', 'brand', 'title',
#        'description'],
#       dtype='object')

# %%
items.describe()
# Out:
#             item_id   external_id   Microcat_id
# count  3.083310e+05  3.083310e+05  3.083310e+05
# mean   2.112174e+12  7.411580e+09  1.643070e+11
# std    1.600193e+10  1.407335e+08  1.874027e+11
# min    3.651828e+11  1.953269e+09  6.600000e+01
# 25%    2.112070e+12  7.403598e+09  3.831000e+03
# 50%    2.112594e+12  7.418076e+09  7.479000e+03
# 75%    2.113711e+12  7.429409e+09  3.913698e+11
# max    2.114864e+12  7.469997e+09  4.217915e+11

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 308331 entries, 0 to 308330
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   item_id          308331 non-null  int64
#  1   external_id      308331 non-null  int64
#  2   StartTime        308331 non-null  object
#  3   param2           308331 non-null  object
#  4   Microcat_id      308331 non-null  int64
#  5   sostoyanie       308331 non-null  object
#  6   predmet_odezhdy  308331 non-null  object
#  7   cvet             308331 non-null  object
#  8   brand            308330 non-null  object
#  9   title            308331 non-null  object
#  10  description      308331 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 28.2+ MB

# %%
items.cvet.value_counts()
# Out:
# cvet
# Чёрный          60779
# Белый           40059
# Разноцветный    28374
# Синий           28155
# Бежевый         26864
# Голубой         23313
# Серый           19380
# Розовый         19344
# Зелёный         18525
# Коричневый      11773
# Красный         10231
# Жёлтый           5954
# Фиолетовый       5175
# Бордовый         4578
# Оранжевый        3827
# Серебряный       1050
# Золотой           950
# Name: count, dtype: int64

# %%
items.param2.value_counts()
# Out:
# param2
# Платья                          80721
# Пиджаки и костюмы               27337
# Верхняя одежда                  26659
# Топы и футболки                 26482
# Другое                          24852
# Рубашки и блузки                23716
# Брюки                           20416
# Юбки                            19247
# Джинсы                          16770
# Джемперы, свитеры, кардиганы    15030
# Нижнее бельё                     9452
# Толстовки и свитшоты             8746
# Купальники                       6587
# Свадебные платья                 2316
# Name: count, dtype: int64

# %%
items[['param2', 'predmet_odezhdy']]
# Out:
#                               param2               predmet_odezhdy
# 0                   Рубашки и блузки              Рубашки и блузки
# 1                    Топы и футболки               Топы и футболки
# 2                             Другое                        Другое
# 3                             Платья                        Платья
# 4                       Нижнее бельё                  Нижнее бельё
# ...                              ...                           ...
# 308326  Джемперы, свитеры, кардиганы  Джемперы, свитеры, кардиганы
# 308327                        Платья                        Платья
# 308328             Пиджаки и костюмы             Пиджаки и костюмы
# 308329                         Брюки                         Брюки
# 308330                         Брюки                         Брюки
#
# [308331 rows x 2 columns]

# %%
items.brand.value_counts()
# Out:
# brand
# Другой        92339
# Без бренда    71353
# H&M           14443
# Zara          10940
# Lime           3247
#               ...
# Marichuell        1
# Danity            1
# SANDS             1
# Cleverly          1
# Lovable           1
# Name: count, Length: 3673, dtype: int64

# %%
report_queries = ProfileReport(queries, title="Queries Profiling Report")

# %%
report_queries.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-06-09 14:20:15.371293&quot;&gt;&lt;title&gt;Queries Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
report_items = ProfileReport(items[['item_id', 'external_id', 'StartTime', 'param2', 'Microcat_id',
       'sostoyanie', 'predmet_odezhdy', 'cvet', 'brand', 'title']],  title="Items Profiling Report")

# %%
report_items
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-06-09 14:21:04.764864&quot;&gt;&lt;title&gt;Items Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
items.description.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 308331 entries, 0 to 308330
# Series name: description
# Non-Null Count   Dtype
# --------------   -----
# 308331 non-null  object
# dtypes: object(1)
# memory usage: 2.4+ MB
